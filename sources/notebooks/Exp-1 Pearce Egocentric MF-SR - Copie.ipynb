# %% [markdown]
# # Exp-1 Pearce Egocentric MF/SR

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
os.chdir(sys.path[0]+"/..")
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\jrusp\Desktop\Code CM

# %%
from added import *
from runwatermaze import perform_pearce, plot_pearce
from agents import CombinedAgent

# %%
plot_geerts(10, platforms=[48, 52, 118, 122, 126, 94, 98, 44], landmarks=[108, 112, 116, 56, 60, 40, 100, 104], figsize=(4,4))

# %% [markdown]
# ### Réplication de la première expérience de Pearce

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = False
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "SR"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = False
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)
# Out:
# Two-way ANOVA on trial and session
#
#                            sum_sq      df           F         PR(>F)
# C(session)           3.031231e+07    24.0   92.371834   0.000000e+00
# C(trial)             9.227600e+06     3.0  224.956894  3.431987e-141
# C(session):C(trial)  2.157764e+06    72.0    2.191811   2.809282e-08
# Residual             1.353641e+08  9900.0         NaN            NaN

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = False
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "SR"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = True
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)
# Out:
# Two-way ANOVA on trial and session
#
#                            sum_sq      df           F    PR(>F)
# C(session)           2.731979e+07    24.0  132.638031  0.000000
# C(trial)             1.326113e+05     3.0    5.150641  0.001476
# C(session):C(trial)  1.078409e+06    72.0    1.745231  0.000102
# Residual             8.496366e+07  9900.0         NaN       NaN

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = True
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "SR"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = False
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)
# Out:
# Two-way ANOVA on trial and session
#
#                            sum_sq      df           F        PR(>F)
# C(session)           4.511587e+07    24.0  146.457441  0.000000e+00
# C(trial)             1.835737e+06     3.0   47.674112  1.395909e-30
# C(session):C(trial)  3.589505e+06    72.0    3.884145  8.953262e-26
# Residual             1.270696e+08  9900.0         NaN           NaN

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = True
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "SR"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = True
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)
# Out:
# Two-way ANOVA on trial and session
#
#                            sum_sq      df           F    PR(>F)
# C(session)           3.209073e+07    24.0  149.079944  0.000000
# C(trial)             1.224508e+05     3.0    4.550836  0.003432
# C(session):C(trial)  9.241688e+05    72.0    1.431099  0.009909
# Residual             8.879415e+07  9900.0         NaN       NaN

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = False
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "MB"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = False
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)
# Out:
# Two-way ANOVA on trial and session
#
#                            sum_sq      df            F         PR(>F)
# C(session)           1.236227e+07    24.0   110.848031   0.000000e+00
# C(trial)             3.960322e+07     3.0  2840.861804   0.000000e+00
# C(session):C(trial)  7.129093e+06    72.0    21.307997  1.321095e-251
# Residual             4.600387e+07  9900.0          NaN            NaN

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = False
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "MB"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = True
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = True
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "MB"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = False
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 25
n_trials = 4
n_agents = 100
mf_allo = True
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "MB"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = True
lesion_DLS = False

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)

# %%
plot_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points)
