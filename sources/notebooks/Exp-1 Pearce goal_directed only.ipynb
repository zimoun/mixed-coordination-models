# %% [markdown]
# # Exp-1 Pearce goal-directed only

# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
os.chdir(sys.path[0]+"/..")
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\jrusp\Desktop\Code CM

# %%
from added import *
from runwatermaze import perform_pearce, plot_pearce
from agents import CombinedAgent

# %%
plot_geerts(10, platforms=[48, 52, 118, 122, 126, 94, 98, 44], landmarks=[108, 112, 116, 56, 60, 40, 100, 104], figsize=(4,4))

# %% [markdown]
# ### Réplication de la première expérience de Pearce

# %%
exp = "first_exp_pearce"
maze_size = 10
n_sessions = 11
n_trials = 4
n_agents = 100
mf_allo = True
sr_lr = 0.07
q_lr = 0.07
inv_temp = 16
gamma = 0.95
eta = 0.03 # reliability learning rate
mpe = 1 # maximum prediction error
A_alpha = 1.8 # Steepness of transition curve MF to SR 
A_beta = 1.1 # Steepness of transition curve SR to MF 
landmark_dist = 4
HPCmode = "SR"
time_limit = 500
starting_points = [243,230,270,257]
lesion_HPC = False
lesion_DLS = True

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)
# Out:
# Two-way ANOVA on trial and session
#
#                            sum_sq      df           F        PR(>F)
# C(session)           2.529490e+06    10.0    8.121402  3.934334e-13
# C(trial)             1.280080e+07     3.0  136.997868  8.074538e-85
# C(session):C(trial)  2.133370e+06    30.0    2.283194  8.470342e-05
# Residual             1.356719e+08  4356.0         NaN           NaN

# %%
HPCmode = "MB"

# %%
perform_pearce(exp, maze_size, n_trials, n_sessions, n_agents, mf_allo, sr_lr, q_lr, inv_temp, gamma, eta, mpe, A_alpha, A_beta, landmark_dist, HPCmode, time_limit, starting_points, lesion_HPC, lesion_DLS)
# Out:
# Two-way ANOVA on trial and session
#
#                            sum_sq      df            F        PR(>F)
# C(session)           2.090237e+06    10.0    22.373406  2.336346e-41
# C(trial)             8.270126e+07     3.0  2950.716750  0.000000e+00
# C(session):C(trial)  1.163399e+06    30.0     4.150917  2.985157e-13
# Residual             4.069595e+07  4356.0          NaN           NaN
